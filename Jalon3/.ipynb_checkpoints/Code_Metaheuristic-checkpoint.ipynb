# %%
import haversine as hs
import pandas as pd
import openpyxl
import numpy as np
import copy
import math
import random
import time

# %%
#Getting the data from the Instances files

def open_excel_employees(file):
    #open and reads the excel with the employees list
    df_employee=pd.read_excel(file,sheet_name="Employees")
    return df_employee

def open_excel_employees_unav(file):
    #open and reads the excel with the employees unavailabilities list
    df_employee_unav=pd.read_excel(file,sheet_name="Employees Unavailabilities")
    return df_employee_unav

def open_excel_tasks(file):
    #open and reads the excel with the task list
    df_tasks=pd.read_excel(file,sheet_name="Tasks")
    return df_tasks

def open_excel_tasks_unav(file):
    #open and reads the excel with the task unavailabilities list
    df_tasks_unav=pd.read_excel(file,sheet_name="Tasks Unavailabilities")
    return df_tasks_unav

def main(path):
    #returns the four dataframes
    employees=open_excel_employees(path)
    employees_unav=open_excel_employees_unav(path)
    tasks=open_excel_tasks(path)
    tasks_unav=open_excel_tasks_unav(path)
    return employees, employees_unav, tasks, tasks_unav

# %%
#Ask user to chose for instance

print("Hello !!!\n")
print("The different data sets for this metaheuristic version are :\n")
print("Instances V2 :\n")
print("1 - Australia\n")
print("2 - Austria\n")
print("3 - Poland\n")
print("4 - Bordeaux\n")
print("5 - Spain\n")

print("Instances V3 :\n")

print("6 - Columbia\n")
print("7 - Ukraine\n")
print("8 - Romania\n")



set_chosen = int(input("Enter a number between 1 and 8\n"))
if set_chosen<1 or set_chosen>8:
    print("error no set available")
    

sets = { 1: "Columbia", 2: "Ukraine", 3: "Romania"}

choice= "InstancesV3/Instance" +sets[set_chosen]+"V3.xlsx"
employees,  employees_unav, tasks, tasks_unav = main(choice)

employees.columns = ['EmployeeName', 'Latitude', 'Longitude', 'Skill', 'Level', 'WorkingStartTime', 'WorkingEndTime']

display(employees.head(5))
display(employees_unav)
display(tasks.head(10))
display(tasks_unav)
# Out:
# Hello !!!
#
# The different data sets for this first version are :
#
# 1 - Columbia
#
# 2 - Ukraine
#
# 3 - Romania
#
# Enter a number between 1 and 3
# 2
#   EmployeeName   Latitude  Longitude     Skill  Level WorkingStartTime  \
# 0       Oksana  49.578874  27.231708  Cleaning      4           8:00am
# 1        Petro  49.280200  26.972661  Cleaning      4           8:00am
# 2         Luba  48.968860  27.069710  Cleaning      4           8:00am
# 3       Ivanna  49.314857  27.586158  Cleaning      1           8:00am
# 4        Marko  49.438534  27.602693  Cleaning      1           8:00am
#
#   WorkingEndTime
# 0         6:00pm
# 1         6:00pm
# 2         6:00pm
# 3         6:00pm
# 4         6:00pm
#   EmployeeName   Latitude  Longitude    Start      End
# 0       Oksana  49.578874  27.231708  10:00am  11:00am
# 1       Ivanna  49.314857  27.586158   8:00am  12:00pm
# 2       Bohdan  49.066276  26.416402   2:00pm   4:00pm
#   TaskId   Latitude  Longitude  TaskDuration     Skill  Level OpeningTime  \
# 0     T1  49.923407  27.696314           240  Cleaning      1      8:00am
# 1     T2  49.570366  27.189972            45  Cleaning      3      8:00am
# 2     T3  49.453035  27.423340            40  Cleaning      4      8:00am
# 3     T4  49.523947  27.204091            45  Cleaning      4      8:00am
# 4     T5  49.438040  27.346264            45  Cleaning      4      8:00am
# 5     T6  49.468770  27.233571            40  Cleaning      2      8:00am
# 6     T7  49.502285  27.311264            45  Cleaning      1      8:00am
# 7     T8  50.042012  26.550276            40  Cleaning      4      8:00am
# 8     T9  50.030112  26.707324            40  Cleaning      4      8:00am
# 9    T10  50.186739  26.906285            40  Cleaning      4      8:00am
#
#   ClosingTime
# 0      6:00pm
# 1      6:00pm
# 2      6:00pm
# 3      6:00pm
# 4      6:00pm
# 5      6:00pm
# 6      6:00pm
# 7      6:00pm
# 8      6:00pm
# 9      6:00pm
# Empty DataFrame
# Columns: [TaskId, Start, End]
# Index: []

# %%
#import data


#We compute all times in minutes after midnight, since the tasks changes everyday
def convert_time_to_minute(dt):
    #converting a datetime string to minutes
    return dt.hour*60+dt.minute




#import data


#We compute all times in minutes after midnight, since the tasks changes everyday
def convert_time_to_minute(dt):
    #converting a datetime string to minutes
    return dt.hour*60+dt.minute


def fill_classes(employees,employees_unav, tasks, tasks_unav):
    dic=dict()
    A = []
    T = []
    
    idx_agent=1
    dic_agent=dict()
    for agent in employees.EmployeeName.unique():
            
    #Filling agent:
            
        name = idx_agent

        #home coords: 
        sub_df=employees[employees.EmployeeName==agent]  
        home_coords = (sub_df.Latitude.iloc[0], sub_df.Longitude.iloc[0] )

        #level:
        level = sub_df.Level.iloc[0] 

        #unvailable: 
        unaivail=[]
        sub_df2= employees_unav[employees_unav.EmployeeName==agent]
        for row in sub_df2.itertuples():
            unaivail.append((convert_time_to_minute(pd.to_datetime(row.Start)), convert_time_to_minute(pd.to_datetime(row.End)), (row.Latitude, row.Longitude) ))
            #print(unaivail)
        #start, end and tasks
        start = convert_time_to_minute(pd.to_datetime(sub_df.WorkingStartTime.iloc[0]))
        #print(start)
        end = convert_time_to_minute(pd.to_datetime(sub_df.WorkingEndTime.iloc[0]))
        #print(end)
        tasks_class= []
        a=Agent(name, home_coords, level, unaivail, start, end, tasks_class)
        A.append(a)
        dic_agent[idx_agent]=agent
        idx_agent+=1
        
     
    
    
    number_task=1   
    for task in tasks.TaskId.unique():  
        
    #Filling Tasks
            
        #number:
        number = number_task

        #coords
        sub_df3 =  tasks[tasks.TaskId==task]
        coords = (sub_df3.Latitude.iloc[0], sub_df3.Longitude.iloc[0] )

        #level
        level = sub_df3.Level.iloc[0] 

        #duration
        duration = sub_df3.TaskDuration.iloc[0]

        #unavailability
        unaivail2=[]
        sub_df4= tasks_unav[tasks_unav.TaskId==task]

        for row in sub_df4.itertuples():
            unaivail2.append((convert_time_to_minute(pd.to_datetime(row.Start)), convert_time_to_minute(pd.to_datetime(row.End)) ))
            #print(unaivail2)
        t= Task(number, coords, level, unaivail2, duration ) 
        T.append(t)
        number_task+=1
        
    #putting in dictionnary
    dic["Agents"]=A
    dic["Tasks"]=T
    
    return dic, [i for i in range(len(dic['Tasks']))],[i for i in range(len(dic['Agents']))], dic_agent

# %%
class Agent():
    
    def __init__(self, idx, home_coords, level, unaivail, start, end, tasks, schedual = {}):
        
        """
        Aide pour comprendre schedual
        -----------
        self.schedual construit une liste des disponibilités de l'agent. Il permettra de déduire
        automatiquement ses disponibilités en prenant les [i,i+1] ou i est pair ! Les indispos
        sont les intervalles de la meme forme avec i impair.
        
        """
        self.idx = idx
        self.home_coords = home_coords
        self.level = level
        self.unaivail = unaivail
        self.start = start
        self.end = end
        self.tasks = tasks
        self.schedual = schedual
        
        if self.schedual == {} :
            self.schedual = [(start, home_coords)]

            for i in range(len(unaivail)):
                self.schedual += [(unaivail[i][0],unaivail[i][2]),(unaivail[i][1],unaivail[i][2])]

            self.schedual += [(end, home_coords)]
            
            for i in range(len(self.schedual)):
                if self.schedual[i][0] > 780 :
                    self.schedual = self.schedual[:i] + [(780, (0,0)),(840, (0,0))] + self.schedual[i:]
                    break

            
    def task_avail_bool(self, new_task):
        """
        Permet de savoir si une task "rentre dans un créneau de disponibilité"
        
        Parameters
        ---------------
        self (méthode), et new_task objets Task considéré
        
        Return
        ---------------
        une liste de couples indiquant un booléen avec l'indice du créneau de disponibilité considéré
        il y aura donc un couple pour chaque créneau de dispo de l'agent. True indiquera qu'on peut
        "rentrer" la task dans le créneau ! C'est aussi ici qu'on prendra en compte les levels
        
        """
        list_avail_bool = [(i, False) for i in range(len(self.schedual)//2)]
        
        for i in range(len(self.schedual)//2):
            
            avail = [self.schedual[2*i],self.schedual[2*i+1]]
            if avail[0][1] == (0,0):
                begin_time, begin_place = avail[0][0], self.schedual[2*i - 2][1]
            else :
                begin_time, begin_place = avail[0][0], avail[0][1]
                
            if avail[1][1] == (0,0):
                end_time, end_place = avail[1][0], self.schedual[2*i+3][1]
            else :
                end_time, end_place = avail[1][0], avail[1][1]
            
            travel_begin_task = math.ceil(hs.haversine(begin_place, new_task.coords)*(6/5))
            travel_end_task = math.ceil(hs.haversine(new_task.coords, end_place)*(6/5))
            
            
            if (self.level >= new_task.level):
                if begin_time + travel_begin_task + travel_end_task + new_task.duration <= end_time: 
                    #the task fits the employee availability gap
                    if len(new_task.unavailability) == 0 : 
                        #the task doesn't have unavailabilities
                        list_avail_bool[i] = (i, True, begin_time + travel_begin_task)
                    else : 
                        #the task have unavailabilities
                        #we assume the task has only one unavailability 
                        begin_unav_task = new_task.unavailability[0][0]
                        end_unav_task = new_task.unavailability[0][1]
                        if begin_time + travel_begin_task + new_task.duration <= begin_unav_task : 
                            #we can do the task before the unavailability
                            list_avail_bool[i] = (i, True, begin_time + travel_begin_task)
                        elif travel_begin_task + begin_time >= end_unav_task :
                            #we can do the task after the unavailability
                            list_avail_bool[i] = (i, True, begin_time + travel_begin_task)
                            
        return list_avail_bool
                            
        
        
        
    def update(self, new_task, avail):
        """
        Permet d'affecter définitivement une tache à un agent et de modifier ses attributs schedual et tasks en conséquences
        
        Parameters
        ----------------
        self (méthode)
        new_task, la nouvelle tache à ajouter
        avail un élément de la liste list_avail_bool
        
        Return
        ----------------
        un update de self avec le schedual modifié en conséquence
        
        """
        #print("On entre dans update")
        x = copy.deepcopy(self.schedual)
        
        self.schedual= x[:2*avail[0]+1] + [(avail[2], new_task.coords, new_task.number), (avail[2] + new_task.duration, new_task.coords, new_task.number)] + x[2*avail[0]+1:]
        
        #print("On a la liste suivante :" , self.tasks)
        #print("On veut y ajouter l'élément suivant :", new_task.number)
        self.tasks.append(new_task.number)
        
        return Agent(self.idx, self.home_coords, self.level, self.unaivail, self.start, self.end, self.tasks, self.schedual)
        
    def delete(self, old_task) :
        
        element_to_delete = []
        
        for i in range(len(self.schedual)) :
            if len(self.schedual[i]) == 3 :
                if self.schedual[i][2] == old_task.number :
                    element_to_delete.append(self.schedual[i])
                    
        for element in element_to_delete :
            
            self.schedual.remove(element)

        #print("On a la liste suivante :" , self.tasks)
        #print("On veut en supprimer l'élément suivant :", old_task.number)
        self.tasks.remove(old_task.number)
        
        
        return Agent(self.idx, self.home_coords, self.level, self.unaivail, self.start, self.end, self.tasks, self.schedual)

# %%
class Task():
    
    def __init__(self, number, coords, level, unavailability, duration, idx_agent = None):
        self.number = number - 1
        self.coords = coords
        self.level = level
        self.unavailability = unavailability
        self.duration = duration
        self.idx_agent = idx_agent
        
    def update(self, idx_agent):
        self.idx_agent = idx_agent
        return Task(self.number + 1, self.coords, self.level, self.unavailability, self.duration, self.idx_agent)

# %%
def copy_parfaite(situation):
    new_situation = dict()
    agents = []
    for agent in situation['Agents']:
        a = copy.deepcopy(agent)
        agents.append(a)
        
    tasks = []
    for task in situation['Tasks']:
        t = copy.deepcopy(task)
        tasks.append(t)
        
    new_situation['Agents'] = agents
    new_situation['Tasks'] = tasks
    
    return new_situation

# %%
def get_cost(situation):
    """
    Parameters
    -----------------
    prends en entrée un dictionnaire à deux clés, 'agent' et 'task', contenant les agent et les tasks de la situation actuelle
    
    Return 
    -----------------
    la valeur de l'objectif pour la situation citéé précedemment
    
    """
    
    task_list = situation['Tasks']
    agent_list = situation['Agents']
    sum_duration = 0
    sum_transportation = 0 
    alpha_1 = 0.8
    alpha_2 = 0.08
    
    for task in task_list :
        
        if task.idx_agent != None :
            sum_duration += task.duration
    
    for agent in agent_list :
        sched = copy.deepcopy(agent.schedual)
        sched.remove((780, (0,0)))
        sched.remove((840, (0,0)))
        for i in range(len(sched)-1):
            sum_transportation += math.ceil(hs.haversine(sched[i][1], sched[i+1][1])*(6/5)) 
            
     
    return - alpha_1*sum_duration + alpha_2*sum_transportation

# %%
def get_neighbors(situation, task_idx, agent_idx):
    """
    Parameters
    -----------------
    prends en entrée un dictionnaire de la situation actuelle, et un indice de la tache à considérer pour la création des neighbors
    
    Return 
    -----------------
    Une liste de situations neighbors pour un changement d'emplacement de la tache considérée
    
    """      
    neighbors = []
    
    situation_copy = copy_parfaite(situation)
    task = situation_copy['Tasks'][task_idx]
    current_agent_idx = task.idx_agent
    #print("Agent qui réalise actuellement la tache considérée :", current_agent_idx)
    if current_agent_idx != None :
        current_agent = situation_copy['Agents'][current_agent_idx]
        #print("Ce que l'agent qui réalise la tache réalise comme liste de taches :", current_agent.tasks)
        r = current_agent.delete(task)
        situation_copy['Agents'][current_agent_idx] = r
        
    agent = situation_copy['Agents'][agent_idx]
    list_avail = agent.task_avail_bool(task)
    if agent_idx==10:
        print(list_avail)
    #print("LIST_AVAIL", list_avail)
    for avail in list_avail :
        
        if avail[1] :
            situation_copy_2  = copy_parfaite(situation_copy)
            #print(situation_copy_2['Agents'][agent_idx].schedual)

            y = copy.deepcopy(situation_copy_2['Agents'][agent_idx])
            situation_copy_2['Agents'][agent_idx] = y.update(task, avail)
            
            z = copy.deepcopy(situation_copy_2['Tasks'][task_idx])
            situation_copy_2['Tasks'][task_idx] = z.update(agent_idx)
            neighbors.append(situation_copy_2)
       
    #print("On sort de get_neighbors")
    return neighbors

# %%
def solution_glouton(initial_state, task_list_idx,agent_list_idx):
    A = initial_state["Agents"]
    T = initial_state["Tasks"]
    
    for task in T:
        agent_idx = random.choice(agent_list_idx)
        agent = A[agent_idx]
        list_avail = agent.task_avail_bool(T[task.number])
        
        for avail in list_avail :
        
            if avail[1] :
                
                
                initial_state_2  = copy_parfaite(initial_state)
                #print(situation_copy_2['Agents'][agent_idx].schedual)

                y = copy.deepcopy(initial_state_2['Agents'][agent_idx])
                
                
                initial_state_2['Agents'][agent_idx] = y.update(initial_state_2['Tasks'][task.number], avail)

                z = copy.deepcopy(initial_state_2['Tasks'][task.number])
                initial_state_2['Tasks'][task.number] = z.update(agent_idx)
                
                initial_state = initial_state_2
            
                pass
            
            else : pass
    
           
    return initial_state

# %%
def simulated_annealing(initial_state, task_list_idx, agent_list_idx, n):
    """Peforms simulated annealing to find a solution"""
    initial_temp = n
    final_temp = 0
    alpha = 0.01
    
    current_temp = initial_temp

    # Start by initializing the current state with the initial state
    current_state = initial_state
    
    while current_temp > final_temp :
        task_idx = random.choice(task_list_idx)
        agent_idx = random.choice(agent_list_idx)
        #print("Tache random sélectionné", task_idx)
        #print("Agent random séléctionné", agent_idx)
        neighbor_list = get_neighbors(current_state, task_idx, agent_idx)
        if len(neighbor_list) != 0 :
            neighbor = random.choice(neighbor_list)
            #print("NEIGHBOR", neighbor['Agents'][0].schedual)
        # Check if neighbor is best so far
            cost_diff = get_cost(current_state) - get_cost(neighbor)
        # if the new solution is better, accept it
            if cost_diff > 0:
                current_state = copy_parfaite(neighbor)
        # if the new solution is not better, accept it with a probability of e^(-cost/temp)
            else:
                if random.uniform(0, 1) < math.exp(-cost_diff / current_temp):
                    current_state = copy_parfaite(neighbor)
        # decrement the temperature
        current_temp -= alpha
]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# L'emploi du temps de l'agent Pavlo:   [(480, (50.056071200000005, 26.9598744)), (650, (49.928827000000005, 28.921460999999997), 90), (690, (49.928827000000005, 28.921460999999997), 90), (780, (0, 0)), (840, (0, 0)), (927, (49.951227, 27.910590000000003), 123), (967, (49.951227, 27.910590000000003), 123), (1080, (50.056071200000005, 26.9598744))]
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
def return_solution(dic, dic_agent):
    #Output formatting

    name="Solution"+sets[set_chosen]+"V3"+"By1.txt"
    f = open(name, "w")
    f.write("taskId;performed;employeeName;startTime;\n")
    for task1 in dic["Tasks"]:
        performed=0
        for agent in dic["Agents"]:
            if task1.number in agent.tasks:
                
                #parcourir agent.schedule
                #des que y'en a un qui est de longueur 3 : sinon pass
                #des que triplet : prendre 3 eme élément [2] : et verifier que == a l'id de la task1
                #si c'est bon prendre elment 0 du schedule et break
                
                
                for element in agent.schedual:
                    
                    if len(element)==3:
                        if element[2]==task1.number:
                            startTime=element[0]
                            performed=1
                            employeeName=dic_agent[agent.idx]
                            break
                    else: pass
        
        if performed == 1:
            best_solution = str(task1.number + 1)+";"+ str(performed)+";"+ str(employeeName) + ";" + str(startTime)+";\n"
            f.write(best_solution)  
        if performed ==0:
            best_solution = str(task1.number + 1)+";"+ str(performed) +";;;\n"
            f.write(best_solution) 
    f.close()
            
            
            

return_solution(solution, dic_agent)

# %%
import folium
import matplotlib.cm as cm
import matplotlib as matplotlib


center = solution['Agents'][0].schedual[0][1] #centre de la carte
Map = folium.Map(location=center, zoom_start=8)

for task in solution['Tasks']:
    folium.Marker(location=task.coords, popup='T'+str(task.number + 1), icon=folium.Icon(color="blue", icon="glyphicon glyphicon-wrench") ).add_to(Map) 
    
lgd_txt = '<span style="color: {col};">{txt}</span>'    #html pour l'affichage de la légende
   
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']*10
count=-1
for agent in solution['Agents']:
    c=0
    for unav in agent.unaivail:
        folium.Marker(location=unav[2], popup='Indispo_'+dic_agent[agent.idx]+'_'+str(c), icon=folium.Icon(color="purple", icon="glyphicon glyphicon-ban-circle") ).add_to(Map) 
        c+=1
    count+=1
    color=colors[count]
    feature_group = folium.FeatureGroup(name= lgd_txt.format( txt= dic_agent[agent.idx], col= color)) #legend
    sch=agent.schedual
    folium.Marker(location=sch[0][1], popup='Maison_'+dic_agent[agent.idx], icon=folium.Icon(color='red', icon="home")).add_to(feature_group) #lieu de sa maison
    pl= folium.PolyLine([sch[0][1]]+[sch[i][1] for i in range(len(sch)) if sch[i][1] != (0,0)]+[sch[0][1]], color=color)
    pl.add_to(feature_group)
    '''folium.plugins.AntPath([sch[0][1]]+[sch[i][1] for i in range(len(sch))]+[sch[0][1]], {
  "delay": 400,
  "dashArray": [
    10,
    20
  ],
  "weight": 5,
  "color": color,
  "pulseColor": color,
  "paused": False,
  "reverse": False,
        "delay":2000
} ).add_to(feature_group)'''
    #on trace entre toutes les tâches, dans l'ordre effectué car nous avons trié notre dic_of_tasks
    feature_group.add_to(Map)

folium.LayerControl().add_to(Map) 
Map.save('map_'+sets[set_chosen]+'V2_meta.html')
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b91d0a91b62140c0b1ef362a1c201c21%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b91d0a91b62140c0b1ef362a1c201c21%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b91d0a91b62140c0b1ef362a1c201c21%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b91d0a91b62140c0b1ef362a1c201c21%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B49.578874400000004%2C%2027.231707899999996%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
import matplotlib.cm as cm
import matplotlib as matplotlib
import matplotlib.pyplot as plt
from gurobipy import *
import folium
from folium import plugins
import matplotlib.dates as mdates
from matplotlib.collections import PolyCollection
import datetime

fig, ax = plt.subplots()
fig.set_size_inches(40, 20)
data = {}

for agent in solution['Agents']:
    sch=agent.schedual
    for i in range(1,(len(sch)//2)):
        if len(sch[2*i-1])>2:
            data['T'+str(sch[2*i-1][2])]= (sch[2*i-1][0], sch[2*i][0], dic_agent[agent.idx])
    data['Lunch \nbreak' + str(agent.idx)] = (780, 840, dic_agent[agent.idx])
    
    if agent.unaivail != []:
        data['Unavail' + str(agent.idx)] = (agent.unaivail[0][0], agent.unaivail[0][1], dic_agent[agent.idx])

cats = {dic_agent[solution['Agents'][i].idx]:i for i in range(len(solution['Agents']))}
colormapping = {dic_agent[solution['Agents'][i].idx]:"C"+str(i) for i in range(len(solution['Agents']))}

verts = {dic_agent[solution['Agents'][i].idx]:[] for i in range(len(solution['Agents']))}
colors = {dic_agent[solution['Agents'][i].idx]:[] for i in range(len(solution['Agents']))}
for task, times in data.items():
    v =  [(times[0], cats[times[2]]-.4),
          (times[0], cats[times[2]]+.4),
          (times[1], cats[times[2]]+.4),
          (times[1], cats[times[2]]-.4),
          (times[0], cats[times[2]]-.4)]
    verts[times[2]].append(v)
    colors[times[2]].append(colormapping[times[2]])
    ax.annotate(task[:12], (times[0]+5, cats[times[2]]), color='w')

for cat in verts.keys():
    bars = PolyCollection(verts[cat], facecolors=colors[cat])
    ax.add_collection(bars)
    
ax.set_yticks([i for i in range(len(solution['Agents']))])
ax.set_yticklabels([dic_agent[solution['Agents'][i].idx] for i in range(len(solution['Agents']))])
ax.set_xticks([i for i in range(480,1140, 60)])
ax.set_xticklabels([str(datetime.timedelta(minutes=i))[:-3] for i in range(480,1140, 60)])

ax.axvline(x = 480, color = "green", linestyle='--', label = "Start of the day") 
ax.axvline(x = 1080, color = "red", linestyle='--', label = "End of the day") 
ax.autoscale()
plt.savefig('timetable_'+sets[set_chosen]+'V2_meta.png', transparent=True)
# Out:
# {'T29': (516, 556, 'Oksana'), 'T21': (713, 753, 'Oksana'), 'T125': (864, 904, 'Oksana'), 'T120': (952, 992, 'Oksana'), 'T121': (1011, 1051, 'Oksana'), 'Lunch \nbreak1': (780, 840, 'Oksana'), 'Unavail1': (600, 660, 'Oksana'), 'T109': (564, 604, 'Petro'), 'T47': (691, 721, 'Petro'), 'T117': (852, 897, 'Petro'), 'T2': (954, 994, 'Petro'), 'Lunch \nbreak2': (780, 840, 'Petro'), 'T104': (610, 650, 'Luba'), 'T116': (929, 969, 'Luba'), 'T43': (998, 1038, 'Luba'), 'Lunch \